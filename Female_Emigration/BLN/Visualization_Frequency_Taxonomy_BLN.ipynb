# %% [markdown]
# ## Analyses of the Frequency_Taxonomy for female emigration

# %% [markdown]
# ### Loading the necessary libraries

# %%
import pandas as pd
import yaml
import matplotlib.pyplot as plt
import numpy as np
import collections

# %% [markdown]
# ### Functions

# %%
def freq_count(results):
    freq_count={}
    for year in results:
        for i in results[year]:
            if year not in freq_count:
                freq_count[year]= i['count']
            else:    
                freq_count[year]+=i['count']
    return freq_count

# %%
def normalize_freq(publication, freq_count):
    normed_results = {}
    for year in freq_count:
        if year>0:
            normed_results[year] = freq_count[year]/float(publication[year][2])
    return normed_results

# %%
def read_query_results(filename):
    with open('./results_TDA/'+filename, 'r') as f:
        query_results = yaml.load(f)
    return query_results

# %%
def plot_freq_count(freq_count):
    plt.plot(freq_count.keys(), freq_count.values())
    plt.show()

# %% [markdown]
# ## 1. Frequencies (without normalised them! ) results using different preprocessing treatments

# %% [markdown]
# ### 2.a) Preprocessing: Normalized + Lemmatized
# Plot the frequency of the query results, in which each word has been normalized (lower-case and removing all
# characters that are not 'a',...,'z') and lemmatized (reducing words to their correct base form).

# %%
query_results_lem=read_query_results('results_taxonomy_lemmatization_1850_1914')
freq_count_lem=freq_count(query_results_lem)
plot_freq_count(freq_count_lem)

# %% [markdown]
# #### 2.b) Example of a normalized + lemmatized query result for 1800

# %%
# Example of the normalized + lemmatized query results for 1800
tdf_lem = pd.DataFrame.from_dict(query_results_lem[1850])
tdf_lem
# Out:
#      count target_word                                              words
# 0        1  emigration  [empire, marriage, mother, respectable, servan...
# 1        1  emigration  [empire, mother, respectable, servant, service...
# 2        1  emigration                         [colonial, colony, mother]
# 3        2  emigration                             [respectable, success]
# 4        1  emigration               [colonial, colony, empire, indecent]
# 5        1  emigration  [colonial, daughter, engagement, marriage, mot...
# 6        1  emigration  [colony, daughter, guardian, loan, service, su...
# 7        1  emigration  [guardian, respectable, servant, success, suit...
# 8        1  emigration  [colony, daughter, engagement, marriage, service]
# 9        1  emigration  [alien, colony, genteel, governess, guardian, ...
# 10       1  emigration  [colonial, colony, engagement, genteel, govern...
# 11       1  emigration                        [servant, service, success]
# 12       1  emigration  [colonial, daughter, failure, genteel, governe...
# 13       1  emigration  [colony, engagement, genteel, loan, respectabl...
# 14       1  emigration  [colonial, colony, daughter, empire, engagemen...
# 15       1  emigration  [empire, engagement, genteel, governess, guard...
# 16       1  emigration  [bookkeeping, empire, genteel, governess, maid...
# 17       1  emigration  [empire, governess, mother, respectable, serva...
# 18       1  emigration                                [failure, marriage]
# 19       2  emigration                                [colonial, service]
# 20       1  emigration  [alien, daughter, genteel, guardian, loan, mai...
# 21       1  emigration  [daughter, empire, guardian, mother, respectab...
# 22       1  emigration           [engagement, loan, respectable, service]
# 23       1  emigration  [colony, empire, governess, guardian, happines...
# 24       1  emigration             [colony, engagement, servant, success]
# 25       1  emigration  [colony, governess, guardian, happiness, marri...
# 26       1  emigration  [bookkeeping, colonial, daughter, engagement, ...
# 27       1  emigration           [colony, respectable, success, suitable]
# 28       1  emigration  [colony, daughter, hardship, mother, respectab...
# 29       1  emigration  [alien, colonial, colony, genteel, loan, marri...
# ..     ...         ...                                                ...
# 421      1  emigration  [daughter, guardian, marriage, mother, respect...
# 422      1  emigration  [guardian, hardship, loan, maid, respectable, ...
# 423      1  emigration  [colonial, colony, daughter, failure, governes...
# 424      1  emigration                                 [guardian, mother]
# 425      1  emigration  [colony, empire, engagement, genteel, respecta...
# 426      1  emigration  [empire, failure, genteel, governess, guardian...
# 427      4  emigration                                         [marriage]
# 428      1  emigration  [colony, engagement, guardian, marriage, respe...
# 429      1  emigration                       [daughter, servant, service]
# 430      1  emigration  [colony, loan, marriage, mother, service, succ...
# 431      1  emigration                                  [mother, service]
# 432      1  emigration  [daughter, loan, marriage, matron, mother, res...
# 433      1  emigration  [daughter, empire, engagement, governess, guar...
# 434      1  emigration  [colonial, colony, daughter, empire, failure, ...
# 435      1  emigration  [empire, respectable, servant, service, superi...
# 436      1  emigration  [colony, engagement, failure, governess, guard...
# 437      1  emigration                   [colony, maid, servant, success]
# 438      1  emigration                  [colonial, colony, loan, success]
# 439      1  emigration                          [colony, empire, servant]
# 440      1  emigration  [colony, daughter, engagement, matron, mother,...
# 441      2  emigration                                          [servant]
# 442      1  emigration  [daughter, mother, respectable, servant, service]
# 443      1  emigration                       [service, success, suitable]
# 444      1  emigration                       [guardian, servant, service]
# 445      1  emigration  [colony, engagement, genteel, guardian, happin...
# 446      1  emigration                                   [daughter, loan]
# 447      1  emigration  [colonial, daughter, engagement, genteel, gove...
# 448      1  emigration              [colonial, colony, guardian, service]
# 449      1  emigration  [governess, guardian, loan, marriage, respecta...
# 450      1  emigration  [colony, failure, marriage, service, teacher, ...
#
# [451 rows x 3 columns]

# %% [markdown]
# ## 2. Normalised frequencies results using different preprocessing treatments
#
# Here, we are examining the total number of isses, articles and words published over the period to see how much our search terms are affected by the way that the number of issues (and articles, and words!) published increases over the measurement period.

# %%
norm_publication=read_query_results('results_normalized_1850_1914')

# %% [markdown]
# We count the total number of words per year, and then count total instances of that search phrase per year, and plot normalised frequency on a graph (x axis is years), to see whether it is a thing that is becoming more or less popular with time

# %% [markdown]
# ### 2.a) Plot of normalized frequencies in which each word has been preprocessed using: normalization + lemmatization

# %%
normed_results_lem=normalize_freq(norm_publication, freq_count_lem)
plot_freq_count(normed_results_lem)
