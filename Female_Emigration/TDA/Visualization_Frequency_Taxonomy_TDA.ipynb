# %% [markdown]
# ## Analyses of the Frequency_Taxonomy for female emigration - using TDA newspapers

# %% [markdown]
# ### Loading the necessary libraries

# %%
import pandas as pd
import yaml
import matplotlib.pyplot as plt
import numpy as np
import collections

# %% [markdown]
# ### Functions

# %%
def freq_count(results):
    freq_count={}
    for year in results:
        for i in results[year]:
            if year not in freq_count:
                freq_count[year]= i['count']
            else:    
                freq_count[year]+=i['count']
    return freq_count

# %%
def normalize_freq(publication, freq_count):
    normed_results = {}
    for year in freq_count:
        if year>0:
            normed_results[year] = freq_count[year]/float(publication[year][2])
    return normed_results

# %%
def read_query_results(filename):
    with open('./results_TDA/'+filename, 'r') as f:
        query_results = yaml.load(f)
    return query_results

# %%
def plot_freq_count(freq_count):
    plt.plot(freq_count.keys(), freq_count.values())
    plt.show()

# %% [markdown]
# ## 1. Frequencies (without normalised them! ) results using different preprocessing treatments

# %% [markdown]
# ###  Preprocessing: Normalized + Lemmatized
# Plot the frequency of the query results, in which each word has been normalized (lower-case and removing all
# characters that are not 'a',...,'z') and lemmatized (reducing words to their correct base form).

# %%
query_results_lem=read_query_results('results_tda_taxonomy_1850_1914')
freq_count_lem=freq_count(query_results_lem)
plot_freq_count(freq_count_lem)

# %% [markdown]
# #### Example of a normalized + lemmatized query result for 1800

# %%
# Example of the normalized + lemmatized query results for 1800
tdf_lem = pd.DataFrame.from_dict(query_results_lem[1850])
tdf_lem
# Out:
#      count target_word                                              words
# 0        1  emigration  [engagement, governess, loan, respectable, ser...
# 1        1  emigration  [bookkeeping, colonial, daughter, engagement, ...
# 2        3  emigration                         [colonial, colony, mother]
# 3        1  emigration  [marriage, respectable, service, success, suit...
# 4        1  emigration                                 [colony, suitable]
# 5        1  emigration  [colonial, colony, guardian, service, success,...
# 6        1  emigration              [daughter, engagement, loan, service]
# 7        1  emigration  [colony, daughter, guardian, hardship, maid, m...
# 8        1  emigration                  [colony, loan, service, suitable]
# 9        1  emigration  [colonial, colony, guardian, respectable, serv...
# 10       1  emigration             [daughter, loan, respectable, service]
# 11       1  emigration                                         [training]
# 12       1  emigration                                  [matron, service]
# 13       1  emigration          [daughter, engagement, success, training]
# 14       1  emigration  [colonial, engagement, governess, guardian, ma...
# 15       1  emigration                    [failure, respectable, success]
# 16       1  emigration  [colonial, colony, empire, guardian, servant, ...
# 17       2  emigration                                         [guardian]
# 18       1  emigration  [colonial, colony, engagement, marriage, serva...
# 19       1  emigration                                     [loan, mother]
# 20       1  emigration  [colonial, colony, empire, guardian, improprie...
# 21       1  emigration  [colonial, colony, guardian, impropriety, resp...
# 22       1  emigration                             [engagement, suitable]
# 23       1  emigration                   [colonial, engagement, suitable]
# 24       1  emigration     [colonial, mother, servant, service, suitable]
# 25       1  emigration  [colonial, colony, daughter, engagement, gente...
# 26       1  emigration                        [colonial, colony, success]
# 27       7  emigration                                          [failure]
# 28       2  emigration                         [colonial, colony, empire]
# 29       1  emigration  [colonial, colony, hardship, marriage, mother,...
# ..     ...         ...                                                ...
# 227      1  emigration  [colonial, colony, daughter, failure, mother, ...
# 228      1  emigration                       [colony, empire, loan, maid]
# 229      1  emigration  [colonial, colony, empire, guardian, respectab...
# 230      1  emigration           [colonial, colony, engagement, suitable]
# 231      1  emigration               [colony, service, success, suitable]
# 232      1  emigration                     [engagement, failure, servant]
# 233      1  emigration                           [colony, loan, marriage]
# 234      1  emigration  [colonial, colony, loan, servant, service, unm...
# 235      1  emigration                          [colony, superintendence]
# 236      1  emigration  [colony, governess, mother, respectable, super...
# 237      1  emigration          [colonial, mother, respectable, suitable]
# 238      3  emigration                                             [maid]
# 239      1  emigration                                [failure, marriage]
# 240      1  emigration  [daughter, genteel, governess, marriage, respe...
# 241      1  emigration  [colonial, colony, empire, engagement, happine...
# 242      1  emigration                     [colony, engagement, suitable]
# 243      1  emigration                         [engagement, maid, mother]
# 244      5  emigration                                         [suitable]
# 245     11  emigration                                          [service]
# 246      1  emigration                             [failure, respectable]
# 247      2  emigration                                         [daughter]
# 248      1  emigration  [engagement, guardian, loan, respectable, serv...
# 249      1  emigration  [colonial, colony, engagement, librarian, loan...
# 250      1  emigration       [colonial, colony, daughter, empire, mother]
# 251      1  emigration  [colonial, colony, engagement, servant, servic...
# 252      1  emigration                              [engagement, service]
# 253      1  emigration                     [colony, respectable, service]
# 254      1  emigration               [colonial, colony, failure, teacher]
# 255      1  emigration                                   [loan, suitable]
# 256      1  emigration  [colonial, colony, empire, guardian, happiness...
#
# [257 rows x 3 columns]

# %% [markdown]
# ## 2. Normalised frequencies results using different preprocessing treatments
#
# Here, we are examining the total number of isses, articles and words published over the period to see how much our search terms are affected by the way that the number of issues (and articles, and words!) published increases over the measurement period.

# %%
norm_publication=read_query_results('results_tda_normalized_1850_1914')

# %% [markdown]
# We count the total number of words per year, and then count total instances of that search phrase per year, and plot normalised frequency on a graph (x axis is years), to see whether it is a thing that is becoming more or less popular with time

# %% [markdown]
# ### Plot of normalized frequencies in which each word has been preprocessed using: normalization + lemmatization

# %%
normed_results_lem=normalize_freq(norm_publication, freq_count_lem)
plot_freq_count(normed_results_lem)
