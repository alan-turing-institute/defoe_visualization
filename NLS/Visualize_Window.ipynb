# %%
#Load the Pandas libraries with alias 'pd' 
import pandas as pd 
import sys
pd.options.display.max_colwidth = 90 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
df = pd.read_csv("./results_NLS/results_window_concordance_updated.csv") 
# Preview the first 5 lines of the loaded data

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df.head()
# Out:
#    date  \
# 0  1771
# 1  1771
# 2  1771
# 3  1771
# 4  1771
#
#                                                                                        title  \
# 0  Encyclopaedia Britannica; or, A dictionary of arts and sciences, compiled upon a new plan
# 1  Encyclopaedia Britannica; or, A dictionary of arts and sciences, compiled upon a new plan
# 2  Encyclopaedia Britannica; or, A dictionary of arts and sciences, compiled upon a new plan
# 3  Encyclopaedia Britannica; or, A dictionary of arts and sciences, compiled upon a new plan
# 4  Encyclopaedia Britannica; or, A dictionary of arts and sciences, compiled upon a new plan
#
#                               edition  \
# 0  First edition, 1771, Volume 1, A-B
# 1  First edition, 1771, Volume 1, A-B
# 2  First edition, 1771, Volume 1, A-B
# 3  First edition, 1771, Volume 1, A-B
# 4  First edition, 1771, Volume 1, A-B
#
#                                                         archive  \
# 0  /home/tdm/datasets/encyclopaedia-britannica-sample/144133901
# 1  /home/tdm/datasets/encyclopaedia-britannica-sample/144133901
# 2  /home/tdm/datasets/encyclopaedia-britannica-sample/144133901
# 3  /home/tdm/datasets/encyclopaedia-britannica-sample/144133901
# 4  /home/tdm/datasets/encyclopaedia-britannica-sample/144133901
#
#                 filename search_term  \
# 0  alto/188082826.34.xml   edinburgh
# 1  alto/188082826.34.xml    scotland
# 2  alto/188082878.34.xml    scotland
# 3  alto/188082930.34.xml   edinburgh
# 4  alto/188082930.34.xml    scotland
#
#                                                                                     sequence
# 0  ['of', 'gentlemen', 'in', 'scotland', 'in', 'three', 'volume', 's', 'vol', 'i', 'edinb...
# 1  ['hundred', 'and', 'sixty', 'copperplates', 'fry', 'a', 'society', 'of', 'gentlemen', ...
# 2  ['botanici', 'le', 'grand', 'encyclopedic', 'erskines', 'inftitutes', 'of', 'the', 'la...
# 3  ['scotland', 'situated', 'in', 'the', 'county', 'of', 'angus', 'about', 'milesnorth', ...
# 4  ['near', 'the', 'danube', 'aberbrothock', 'one', 'of', 'the', 'royal', 'boroughs', 'of...

# %%
def visualize_term(df, term):
    df_term=df.loc[df['search_term'] == term]
    term_list=df_term['sequence']
    window_left=[]
    window_right=[]
    term_l=[]
    for i in term_list:
        idx=i.index(term)
        term_size=len(term)+2
        window_left.append(i[2:idx-3])
        window_right.append(i[idx+term_size:])
        term_l.append(term)
    v_d = {'words_left':window_left, 'term':term_l, 'words_right': window_right}
    v_df = pd.DataFrame(v_d)
    f_vdf= v_df[['words_left', 'term', 'words_right']]
    return f_vdf

# %%
edinburgh_vdf= visualize_term(df, "edinburgh")
edinburgh_vdf
# Out:
#                                                                                    words_left  \
# 0                of', 'gentlemen', 'in', 'scotland', 'in', 'three', 'volume', 's', 'vol', 'i'
# 1    scotland', 'situated', 'in', 'the', 'county', 'of', 'angus', 'about', 'milesnorth', 'of'
# 2                       the', 'frith', 'of', 'forth', 'about', 'ten', 'miles', 'n', 'w', 'of'
# 3             of', 'arts', 'and', 'the', 'academy', 'of', 'painting', 'in', 'scotland', 'the'
# 4    hours', 'thus', 'examp', 'iii', 'suppose', 'the', 'dillance', 'between', 'london', 'and'
# 5                    to', 'be', 'miles', 'and', 'that', 'a', 'courier', 'sets', 'out', 'from'
# 6           they', 'will', 'meet', 'suppose', 'the', 'courier', 'that', 'sets', 'out', 'from'
# 7   these', 'four', 'years', 'the', 'anabaptifts', 'have', 'formed', 'a', 'congregation', ...
# 8   swe', 'applied', 'to', 'the', 'preachers', 'of', 'the', 'anabaptijl', 'congregation', ...
# 9          in', 'dudding', 'itonloch', 'a', 'freihwater', 'lake', 'within', 'a', 'mile', 'of'
# 10  alexander', 'monro', 'present', 'professor', 'of', 'anatofhy', 'in', 'the', 'universit...
# 11                            long', 'j', 'and', 'n', 'lat', 'about', 'miles', 'n', 'e', 'of'
# 12             entrance', 'of', 'the', 'frith', 'of', 'forth', 'about', 'miles', 'east', 'of'
# 13                                            i', 'w', 'a', 's', 't', 'e', 'b', 'o', 'o', 'k'
# 14                                                r', 'b', 'o', 'o', 'k', 'k', 'e', 'journal'
# 15     hope', 'profelfor', 'of', 'medicine', 'and', 'botany', 'in', 'the', 'univerflty', 'of'
# 16     detergent', 'qualities', 'and', 'as', 'such', 'are', 'admitted', 'into', 'both', 'the'
# 17            them', 'to', 'dr', 'hope', 'professor', 'of', 'medicine', 'and', 'botany', 'in'
# 18         coalt', 'of', 'fife', 'in', 'scotland', 'about', 'ten', 'miles', 'northwell', 'of'
#
#          term  \
# 0   edinburgh
# 1   edinburgh
# 2   edinburgh
# 3   edinburgh
# 4   edinburgh
# 5   edinburgh
# 6   edinburgh
# 7   edinburgh
# 8   edinburgh
# 9   edinburgh
# 10  edinburgh
# 11  edinburgh
# 12  edinburgh
# 13  edinburgh
# 14  edinburgh
# 15  edinburgh
# 16  edinburgh
# 17  edinburgh
# 18  edinburgh
#
#                                                                                   words_right
# 0              'printed', 'for', 'a', 'bell', 'and', 'c', 'macearquhar', 'aid', 'sold', 'by']
# 1                 'its', 'west', 'long', 'is', 'and', 'n', 'lat', 'there', 'was', 'formerly']
# 2    'abergaveny', 'in', 'monmouthfhire', 'england', 'a', 'wellbuilt', 'town', 'lying', 'm...
# 3    'society', 'college', 'of', 'phylicians', 'and', 'musical', 'society', 'all', 'which'...
# 4                  'to', 'be', 'miles', 'and', 'that', 'a', 'courier', 'sets', 'out', 'from']
# 5             'running', 'at', 'the', 'rate', 'of', 'miles', 'an', 'hour', 'another', 'sets']
# 6                'runs', 'x', 'miles', 'and', 'the', 'other', 'y', 'miles', 'before', 'they']
# 7      'which', 'is', 'the', 'first', 'appearance', 'they', 'ever', 'made', 'in', 'scotland']
# 8           'from', 'whom', 'we', 'had', 'the', 'above', 'account', 'the', 'same', 'conduit']
# 9       'the', 'hiftrionica', 'or', 'duikyspotted', 'duck', 'of', 'edwards', 'is', 'of', 'a']
# 10   'published', 'his', 'treatise', 'de', 'venis', 'lymphaticis', 'valvulofis', 'in', 'th...
# 11   'st', 'andrews', 'was', 'formerly', 'an', 'archbifliops', 'see', 'but', 'at', 'present']
# 12               'in', 'ifw', 'long', 'and', 'n', 'lat', 'beryl', 'in', 'natural', 'history']
# 13            'the', 'ill', 'of', 'january', 'i', 'inventory', 'of', 'the', 'money', 'goods']
# 14            'the', 'ill', 'of', 'january', 'sundries', 'drs', 'to', 'stock', 'cajh', 'for']
# 15   'immediately', 'after', 'the', 'dodors', 'adwiiition', 'to', 'the', 'botanical', 'cha...
# 16   'and', 'london', 'difpenfatories', 'the', 'aparine', 'gallium', 'bc', 'pofless', 'the...
# 17       'dr', 'hope', 'sowed', 'them', 'in', 'the', 'botanical', 'garden', 'arid', 'collet']
# 18                  'w', 'long', 'and', 'n', 'lat', 'i', 'brush', 'an', 'inllrument', 'made']

# %%
woman_vdf= visualize_term(df, "woman")
woman_vdf
# Out:
#                                                                                    words_left  \
# 0               that', 'furrounc', 't', 'it', 'in', 'the', 'same', 'manner', 'a', 'beautiful'
# 1               menage', 'academy', 'figure', 'a', 'drawing', 'of', 'a', 'naked', 'man', 'or'
# 2            they', 'were', 'kept', 'in', 'the', 'treasury', 'of', 'saturnus', 'actress', 'a'
# 3          the', 'prince', 'or', 'a', 'vacancy', 'of', 'the', 'throne', 'administratrix', 'a'
# 4                ad', 'ventrem', 'infpiciendum', 'in', 'law', 'a', 'writ', 'by', 'which', 'a'
# 5      virtue', 'attribute', 'or', 'perfedion', 'a', 'eon', 'in', 'mythology', 'the', 'firli'
# 6               the', 'mutual', 'plighting', 'of', 'troth', 'between', 'a', 'man', 'and', 'a'
# 7                     they', 'are', 'the', 'ilfue', 'of', 'a', 'white', 'man', 'and', 'black'
# 8      hatnaxohii', 'amazon', 'in', 'a', 'general', 'fcnfe', 'denotes', 'a', 'bold', 'daring'
# 9   temperance', 'and', 'sobriety', 'andria', 'among', 'some', 'naturalists', 'denotes', '...
# 10          anni', 'nubiles', 'in', 'law', 'denotes', 'the', 'marriageable', 'age', 'of', 'a'
# 11  strong', 'implements', 'of', 'husbandry', 'his', 'wellfed', 'oxen', 'and', 'ahale', 'y...
# 12         and', 'caves', 'upon', 'it', 'containing', 'near', 'monks', 'and', 'hermits', 'no'
# 13          independent', 'being', 'that', 'jesus', 'christ', 'was', 'not', 'born', 'of', 'a'
# 14                                                                        side', 'and', 'the'
# 15         last', 'are', 'afterwards', 'filled', 'with', 'a', 'fine', 'plaster', 'bride', 'a'
# 16        brides', 'for', 'matters', 'being', 'agreed', 'on', 'between', 'them', 'two', 'the'
# 17                   confusion', 'of', 'species', 'that', 'is', 'to', 'say', 'a', 'man', 'or'
# 18                     a', 'man', 'with', 'a', 'man', 'or', 'man', 'unnaturally', 'with', 'a'
#
#      term  \
# 0   woman
# 1   woman
# 2   woman
# 3   woman
# 4   woman
# 5   woman
# 6   woman
# 7   woman
# 8   woman
# 9   woman
# 10  woman
# 11  woman
# 12  woman
# 13  woman
# 14  woman
# 15  woman
# 16  woman
# 17  woman
# 18  woman
#
#                                                                                   words_right
# 0           'in', 'a', 'crowd', 'abftra', 'as', 'our', 'thoughts', 'and', 'engrosses', 'our']
# 1            'taken', 'from', 'the', 'life', 'which', 'is', 'usually', 'done', 'on', 'paper']
# 2           'who', 'performs', 'a', 'part', 'upon', 'the', 'stage', 'women', 'adors', 'wene']
# 3    'who', 'afts', 'as', 'administrator', 'admirabilis', 'in', 'botany', 'a', 'fynonime',...
# 4                'is', 'to', 'be', 'searched', 'vhether', 'she', 'be', 'with', 'child', 'by']
# 5    'according', 'to', 'the', 'phoenician', 'writers', 'a', 'eon', 'among', 'anatomills',...
# 6                'to', 'marry', 'each', 'other', 'affiche', 'a', 'term', 'used', 'by', 'the']
# 7             'and', 'at', 'a', 'didanee', 'might', 'be', 'taken', 'for', 'europeans', 'but']
# 8    'amazons', 'were', 'an', 'ancient', 'nation', 'of', 'women', 'inhabiting', 'that', 'p...
# 9      'see', 'hermaphrodite', 'andria', 'in', 'geography', 'a', 'town', 'of', 'italy', 'in']
# 10        'viz', 'after', 'ftie', 'has', 'arrived', 'at', 'twelve', 'anniented', 'in', 'law']
# 11         'his', 'daughter', 'and', 'point', 'ihg', 'to', 'them', 'said', 'these', 'romans']
# 12         'is', 'allowed', 'to', 'come', 'within', 'sight', 'of', 'their', 'convents', 'it']
# 13         'but', 'brought', 'his', 'body', 'with', 'him', 'from', 'heaven', 'and', 'denied']
# 14  , 'on', 'the', 'sinister', 'but', 'here', 'the', 'woman', 'is', 'fuppoftd', 'not', 'an...
# 15      'newly', 'married', 'among', 'the', 'greeks', 'it', 'was', 'customary', 'for', 'the']
# 16   'hat', 'contrived', 'and', 'managed', 'the', 'match', 'having', 'haved', 'the', 'brid...
# 17                    'with', 'a', 'brute', 'beast', 'or', 'sexes', 'as', 'a', 'man', 'with']
# 18               'it', 'is', 'said', 'this', 'sin', 'against', 'god', 'and', 'nature', 'was']

# %%
maid_vdf= visualize_term(df, "maid")
maid_vdf
# Out:
#                                                                   words_left  \
# 0  sum', 'of', 'money', 'paid', 'to', 'the', 'lord', 'upon', 'marrying', 'a'
#
#    term  \
# 0  maid
#
#                                                                          words_right
# 0   'within', 'his', 'manor', 'amacaches', 'a', 'people', 'of', 'brazil', 'in', 's']

# %%
scoltand_vdf= visualize_term(df, "scotland")
scoltand_vdf
# Out:
#                                                                                    words_left  \
# 0    hundred', 'and', 'sixty', 'copperplates', 'fry', 'a', 'society', 'of', 'gentlemen', 'in'
# 1   botanici', 'le', 'grand', 'encyclopedic', 'erskines', 'inftitutes', 'of', 'the', 'law'...
# 2       near', 'the', 'danube', 'aberbrothock', 'one', 'of', 'the', 'royal', 'boroughs', 'of'
# 3        lat', 'there', 'was', 'formerly', 'one', 'of', 'the', 'richest', 'monasteries', 'in'
# 4                  in', 'this', 'town', 'it', 'was', 'founded', 'by', 'king', 'william', 'of'
# 5                 by', 'king', 'john', 'aberdeen', 'the', 'name', 'of', 'two', 'cities', 'in'
# 6       by', 'very', 'able', 'profefiors', 'aberdour', 'a', 'small', 'town', 'in', 'fifdhire'
# 7        the', 'encouragement', 'of', 'arts', 'and', 'the', 'academy', 'of', 'painting', 'in'
# 8                   of', 'yards', 'each', 'that', 'is', 'square', 'yards', 'an', 'acre', 'in'
# 9       statute', 'acre', 'is', 'about', 'roods', 'and', 'falls', 'standard', 'measure', 'of'
# 10                  a', 'kingdom', 'or', 'state', 'high', 'admiral', 'in', 'the', 'law', 'of'
# 11  judge', 'inverted', 'with', 'supreme', 'jurifdiftion', 'in', 'all', 'maritime', 'cause...
# 12                                                                                    within'
# 13       of', 'vermes', 'tertacea', 'see', 'voluta', 'high', 'court', 'of', 'admiralty', 'in'
# 14  civil', 'law', 'obtains', 'kings', 'advocate', 'is', 'the', 'principal', 'crownlawyer'...
# 15   to', 'prosecute', 'crimes', 'at', 'his', 'own', 'instance', 'faculty', 'advocates', 'in'
# 16    antiquities', 'the', 'second', 'in', 'englilh', 'upon', 'the', 'municipal', 'law', 'of'
# 17  an', 'advocate', 'or', 'lawyer', 'is', 'elteemed', 'the', 'genteeleft', 'profession', ...
# 18               is', 'the', 'bristol', 'channel', 'and', 'many', 'of', 'the', 'friths', 'of'
# 19                 will', 'do', 'much', 'more', 'by', 'the', 'addition', 'of', 'manure', 'in'
# 20       experience', 'and', 'agreeable', 'to', 'the', 'pfaice', 'in', 'those', 'parts', 'of'
# 21         exhausting', 'too', 'much', 'of', 'the', 'vegetable', 'food', 'the', 'lands', 'in'
# 22             been', 'long', 'used', 'as', 'manures', 'are', 'among', 'the', 'richest', 'in'
# 23             most', 'proper', 'for', 'each', 'kind', 'the', 'foils', 'most', 'common', 'in'
# 24       condruftion', 'and', 'particular', 'uses', 'i', 'of', 'the', 'scots', 'plough', 'in'
# 25            repeated', 'trials', 'by', 'those', 'who', 'attempted', 'to', 'use', 'it', 'in'
# 26   cenfequently', 'more', 'easily', 'drawn', 'than', 'any', 'other', 'plough', 'used', 'in'
# 27  ploughing', 'lee', 'or', 'opening', 'up', 'grassgrounds', 'the', 'common', 'pradtice',...
# 28        horse', 'is', 'sufficient', 'to', 'draw', 'the', 'harrow', 'commonly', 'used', 'in'
# 29            two', 'pair', 'there', 'are', 'several', 'kinds', 'of', 'harrows', 'used', 'in'
# ..                                                                                        ...
# 67       the', 'island', 'of', 'anglesey', 'in', 'wales', 'and', 'in', 'aberdeenfhire', 'irt'
# 68             jw', 'long', 'and', 'ndat', 'athol', 'a', 'diftridt', 'of', 'perthfhire', 'in'
# 69  south', 'of', 'vienna', 'badenoch', 'an', 'inland', 'coprttry', 'of', 'invernessrtiire...
# 70                  of', 'arundo', 'see', 'arundo', 'bamff', 'or', 'banff', 'a', 'town', 'of'
# 71                   one', 'place', 'lying', 'on', 'the', 'coalt', 'of', 'e', 'lothain', 'in'
# 72   fols', 'french', 'money', 'eatable', 'ground', 'that', 'land', 'which', 'lay', 'between'
# 73               and', 'france', 'in', 'england', 'the', 'ax', 'is', 'preferred', 'and', 'in'
# 74                and', 'n', 'lat', 'benbecula', 'one', 'of', 'the', 'western', 'isles', 'of'
# 75            elong', 'and', 'onlau', 'bernera', 'one', 'of', 'the', 'western', 'isles', 'of'
# 76                  and', 'n', 'lat', 'bervy', 'a', 'seaport', 'town', 'and', 'borough', 'of'
# 77        lat', 'berwick', 'a', 'boroughtown', 'on', 'the', 'borders', 'of', 'england', 'and'
# 78       it', 'sends', 'two', 'members', 'to', 'parliament', 'awzjberwick', 'a', 'town', 'of'
# 79          a', 'bill', 'of', 'exchange', 'when', 'the', 'parties', 'concerned', 'live', 'in'
# 80  in', 'england', 'there', 'are', 'twentyfour', 'bilhoprics', 'and', 'two', 'archbilhopr...
# 81  in', 'the', 'counties', 'pf', 'northumberland', 'cumberland', 'westmoreland', 'tmdfeve...
# 82                       blair', 'of', 'athol', 'a', 'small', 'tow', 'n', 'of', 'athol', 'in'
# 83               boriftkenes', 'bog', 'or', 'bog', 'of', 'gight', 'a', 'foiall', 'town', 'of'
# 84                see', 'hat', 'bonnets', 'are', 'llill', 'used', 'in', 'many', 'parts', 'of'
# 85            of', 'barony', 'see', 'law', 'tit', 'inferior', 'judges', 'and', 'courts', 'of'
# 86     all', 'in', 'all', 'mountainous', 'countries', 'as', 'wales', 'the', 'highlands', 'of'
# 87        more', 'plants', 'than', 'were', 'ever', 'formerly', 'supposed', 'to', 'grow', 'in'
# 88                   a', 'chalky', 'soil', 'this', 'herb', 'which', 'is', 'a', 'native', 'of'
# 89         garden', 'of', 'sir', 'alexander', 'dick', 'and', 'many', 'other', 'gardens', 'in'
# 90    respiration', 'brechin', 'a', 'boroughtown', 'of', 'the', 'county', 'of', 'angus', 'in'
# 91         britain', 'is', 'into', 'south', 'and', 'north', 'britain', 'or', 'england', 'and'
# 92   or', 'ironwire', 'broadalbin', 'a', 'diftritt', 'or', 'county', 'of', 'perthfhire', 'in'
# 93  wolfembuttle', 'burntisland', 'a', 'parliamenttown', 'on', 'the', 'coalt', 'of', 'fife...
# 94      de', 'bucb', 'buchan', 'a', 'country', 'or', 'district', 'of', 'aberdeenftiire', 'in'
# 95             hersr', 'broom', 'in', 'botany', 'see', 'ruscus', 'bute', 'an', 'iftand', 'of'
# 96             to', 'the', 'public', 'lawsin', 'being', 'byrlaw', 'orgya', 'law', 'awr', 'in'
#
#         term  \
# 0   scotland
# 1   scotland
# 2   scotland
# 3   scotland
# 4   scotland
# 5   scotland
# 6   scotland
# 7   scotland
# 8   scotland
# 9   scotland
# 10  scotland
# 11  scotland
# 12  scotland
# 13  scotland
# 14  scotland
# 15  scotland
# 16  scotland
# 17  scotland
# 18  scotland
# 19  scotland
# 20  scotland
# 21  scotland
# 22  scotland
# 23  scotland
# 24  scotland
# 25  scotland
# 26  scotland
# 27  scotland
# 28  scotland
# 29  scotland
# ..       ...
# 67  scotland
# 68  scotland
# 69  scotland
# 70  scotland
# 71  scotland
# 72  scotland
# 73  scotland
# 74  scotland
# 75  scotland
# 76  scotland
# 77  scotland
# 78  scotland
# 79  scotland
# 80  scotland
# 81  scotland
# 82  scotland
# 83  scotland
# 84  scotland
# 85  scotland
# 86  scotland
# 87  scotland
# 88  scotland
# 89  scotland
# 90  scotland
# 91  scotland
# 92  scotland
# 93  scotland
# 94  scotland
# 95  scotland
# 96  scotland
#
#                                                                                   words_right
# 0               'in', 'three', 'volume', 's', 'vol', 'i', 'edinburgh', 'printed', 'for', 'a']
# 1    'essays', 'on', 'husbandry', 'foreign', 'eflays', 'on', 'agriculture', 'essays', 'phy...
# 2    'situated', 'in', 'the', 'county', 'of', 'angus', 'about', 'milesnorth', 'of', 'edinb...
# 3                'in', 'this', 'town', 'it', 'was', 'founded', 'by', 'king', 'william', 'of']
# 4       'about', 'the', 'year', 'o', 'in', 'honour', 'of', 'thomas', 'becket', 'archbiffiop']
# 5           'called', 'the', 'old', 'and', 'new', 'towns', 'situated', 'on', 'the', 'german']
# 6                     'on', 'the', 'frith', 'of', 'forth', 'about', 'ten', 'miles', 'n', 'w']
# 7    'the', 'edinburgh', 'society', 'college', 'of', 'phylicians', 'and', 'musical', 'soci...
# 8    'contains', 'square', 'roods', 'square', 'rood', 'is', 'square', 'falls', 'square', '...
# 9           'a', 'creme', 'in', 'old', 'lawbooks', 'signifies', 'ten', 'acres', 'of', 'land']
# 10   'a', 'judge', 'inverted', 'with', 'supreme', 'jurifdiftion', 'in', 'all', 'maritime',...
# 11   'see', 'law', 'title', 'supreme', 'judges', 'and', 'courts', 'of', 'scotland', 'admir...
# 12   'see', 'law', 'title', 'supreme', 'judges', 'and', 'courts', 'of', 'scotland', 'admir...
# 13      'the', 'court', 'in', 'which', 'the', 'highadmiral', 'is', 'judge', 'see', 'admiral']
# 14            'his', 'business', 'is', 'to', 'adt', 'as', 'a', 'public', 'prosecutor', 'and']
# 15        'a', 'refpedlable', 'body', 'of', 'lawyers', 'who', 'plead', 'in', 'all', 'causes']
# 16                   'and', 'in', 'the', 'third', 'he', 'is', 'obliged', 'to', 'defend', 'a']
# 17   'many', 'gentlemen', 'of', 'fortune', 'take', 'the', 'degree', 'of', 'advocate', 'wit...
# 18   't', 'estuaries', 'in', 'ancient', 'baths', 'were', 'secret', 'palfages', 'from', 'the']
# 19          'it', 'is', 'the', 'universal', 'practice', 'to', 'dung', 'lands', 'that', 'are']
# 20        'where', 'lime', 'is', 'most', 'used', 'when', 'employed', 'for', 'the', 'purpose']
# 21   'capable', 'of', 'the', 'greatefi', 'improvement', 'by', 'lime', 'are', 'the', 'outfi...
# 22        'and', 'have', 'been', 'kept', 'almost', 'constantly', 'in', 'tillage', 'vol', 'i']
# 23               'are', 'the', 'black', 'loamy', 'the', 'clay', 'the', 'sandy', 'and', 'the']
# 24               'this', 'plough', 'is', 'dill', 'the', 'mod', 'common', 'and', 'the', 'mod']
# 25                 'they', 'have', 'been', 'obliged', 'to', 'give', 'it', 'up', 'so', 'many']
# 26         'and', 'as', 'it', 'is', 'hotter', 'the', 'friction', 'is', 'also', 'diminiffied']
# 27            'is', 'to', 'plough', 'it', 'as', 'shallow', 'and', 'narrow', 'as', 'pofiible']
# 28    'sometimes', 'two', 'of', 'them', 'go', 'abreast', 'and', 'sometimes', 'three', 'when']
# 29                'the', 'common', 'one', 'is', 'so', 'well', 'known', 'that', 'it', 'needs']
# ..                                                                                        ...
# 67       'ascaris', 'in', 'zoology', 'agenus', 'of', 'infeds', 'belonging', 'to', 'vol', 'i']
# 68     'from', 'whence', 'the', 'ancient', 'and', 'noble', 'family', 'of', 'murray', 'takes']
# 69   'lying', 'between', 'aberdeenfliire', 'and', 'lochaber', 'badenweiller', 'a', 'town',...
# 70   'which', 'gives', 'name', 'to', 'a', 'county', 'lying', 'between', 'aberdeenlhire', '...
# 71                'at', 'the', 'mouth', 'of', 'the', 'frith', 'of', 'forth', 'bassaim', 'or']
# 72        'and', 'england', 'when', 'the', 'kingdoms', 'were', 'diltin', 'ct', 'to', 'which']
# 73          'they', 'use', 'for', 'this', 'purpose', 'a', 'machine', 'called', 'a', 'maiden']
# 74      'bengalis', 'or', 'bancahs', 'seebangans', 'bench', 'or', 'banc', 'in', 'law', 'see']
# 75    'lying', 'in', 'lat', 'bernicola', 'in', 'ornithology', 'the', 'trivial', 'name', 'of']
# 76   'situated', 'on', 'the', 'german', 'ocean', 'about', 'miles', 'fouthweft', 'of', 'abe...
# 77             'situated', 'on', 'the', 'north', 'side', 'of', 'the', 'river', 'tweed', 'in']
# 78         'situated', 'at', 'the', 'entrance', 'of', 'the', 'frith', 'of', 'forth', 'about']
# 79            'it', 'is', 'termed', 'an', 'inland', 'bill', 'as', 'to', 'the', 'solemnities']
# 80   'none', 'at', 'all', 'in', 'ireland', 'eighteen', 'biftioprics', 'and', 'four', 'arch...
# 81            'it', 'was', 'formerly', 'taken', 'for', 'a', 'certain', 'rent', 'of', 'money']
# 82   'situated', 'about', 'twentyeight', 'miles', 'north', 'of', 'perth', 'blairia', 'in',...
# 83                                                                               'g', 'near']
# 84   'bonnet', 'in', 'fortification', 'a', 'small', 'work', 'confiding', 'of', 'two', 'fac...
# 85   'boroughenglish', 'a', 'customary', 'defeent', 'of', 'lands', 'or', 'tenements', 'in'...
# 86    'the', 'black', 'cattle', 'are', 'exceedingly', 'small', 'but', 'hardy', 'and', 'when']
# 87   'after', 'this', 'acquisition', 'the', 'dr', 'judiciously', 'changed', 'the', 'object...
# 88       'gives', 'cloth', 'a', 'most', 'beautiful', 'yellow', 'colour', 'and', 'is', 'much']
# 89           'the', 'root', 'is', 'found', 'by', 'repeated', 'trials', 'to', 'be', 'equally']
# 90          'about', 'miles', 'northeast', 'of', 'dundee', 'w', 'long', 'north', 'lat', 'qd']
# 91     'new', 'britain', 'a', 'large', 'country', 'of', 'north', 'america', 'called', 'also']
# 92    'bordering', 'upon', 'argyleftiire', 'it', 'gives', 'the', 'title', 'of', 'earl', 'to']
# 93          'about', 'ten', 'miles', 'northwell', 'of', 'edinburgh', 'w', 'long', 'and', 'n']
# 94                  'it', 'gives', 'the', 'title', 'of', 'earl', 'to', 'the', 'noble', 'and']
# 95               'lying', 'in', 'the', 'mouth', 'of', 'the', 'frith', 'of', 'clyde', 'south']
# 96   'ate', 'made', 'and', 'determined', 'by', 'neighbours', 'eledfed', 'by', 'common', 'c...
#
# [97 rows x 3 columns]

# %%
man_vdf= visualize_term(df, "man")
man_vdf
# Out:
#                                                                                    words_left  \
# 0   selfevident', 'or', 'previously', 'difeovered', 'principles', 'it', 'is', 'well', 'if'...
# 1          before', 'him', 'in', 'one', 'uninterrupted', 'chain', 'but', 'where', 'is', 'the'
# 2     hitherto', 'adopted', 'we', 'will', 'however', 'venture', 'to', 'affirm', 'that', 'any'
# 3            the', 'evidence', 'arising', 'from', 'the', 'single', 'te', 'ftimony', 'of', 'a'
# 4           called', 'the', 'menage', 'academy', 'figure', 'a', 'drawing', 'of', 'a', 'naked'
# 5                 curiam', 'in', 'the', 'engliffi', 'law', 'a', 'writ', 'lying', 'where', 'a'
# 6            alluding', 'to', 'that', 'species', 'of', 'earth', 'of', 'which', 'the', 'first'
# 7               ceylon', 'on', 'the', 'top', 'of', 'which', 'they', 'believe', 'the', 'first'
# 8                is', 'that', 'title', 'or', 'defiguation', 'which', 'is', 'given', 'to', 'a'
# 9                   follows', 'it', 'thus', 'in', 'the', 'phrase', 'he', 'is', 'an', 'honejl'
# 10    cats', 'represented', 'sometimes', 'like', 'a', 'cat', 'and', 'foinetimes', 'like', 'a'
# 11             in', 'the', 'way', 'of', 'conjefture', 'which', 'will', 'never', 'lead', 'any'
# 12              looked', 'upon', 'this', 'attempt', 'as', 'the', 'foible', 'of', 'a', 'great'
# 13      what', 'faculty', 'of', 'the', 'soul', 'the', 'difpofltion', 'arises', 'in', 'mortal'
# 14              and', 'chains', 'and', 'dark', 'chambers', 'arid', 'st', 'raw', 'for', 'what'
# 15         in', 'law', 'denotes', 'the', 'mutual', 'plighting', 'of', 'troth', 'between', 'a'
# 16                both', 'sexes', 'are', 'enabled', 'to', 'do', 'certain', 'ads', 'thus', 'a'
# 17             foecage', 'voli', 'no', 'age', 'twentyone', 'is', 'called', 'full', 'age', 'a'
# 18  agenda', 'among', 'philosophers', 'and', 'divines', 'signifies', 'the', 'duties', 'whi...
# 19           rising', 'are', 'apt', 'to', 'entangle', 'or', 'choke', 'the', 'beam', 'another'
# 20               negroes', 'as', 'monders', 'they', 'are', 'the', 'ilfue', 'of', 'a', 'white'
# 21                 between', 'the', 'value', 'of', 'effedls', 'or', 'money', 'due', 'to', 'a'
# 22                 and', 'their', 'amount', 'is', 'nothing', 'thus', 'tool', 'due', 'to', 'a'
# 23               the', 'rest', 'found', 'that', 'their', 'ihares', 'amounted', 'to', 'r', 'a'
# 24  quantity', 'that', 'will', 'result', 'from', 'this', 'fubflitution', 'will', 'necefiar...
# 25   by', 'which', 'means', 'the', 'goods', 'are', 'divided', 'without', 'partiality', 'each'
# 26             name', 'who', 'are', 'represented', 'as', 'governed', 'by', 'a', 'queen', 'no'
# 27  and', 'fubjedt', 'themselves', 'in', 'civil', 'matters', 'to', 'every', 'ordinance', 'of'
# 28                 than', 'in', 'the', 'flomach', 'but', 'the', 'texture', 'of', 'them', 'in'
# 29     the', 'common', 'fern', 'the', 'pancreatic', 'dust', 'is', 'sometimes', 'double', 'in'
# ..                                                                                        ...
# 64  of', 'the', 'monaftical', 'life', 'without', 'observing', 'celibacy', 'and', 'maintain...
# 65               between', 'two', 'rows', 'of', 'flakes', 'about', 'the', 'height', 'of', 'a'
# 66                      no', 'flank', 'it', 'is', 'also', 'a', 'general', 'rule', 'that', 'a'
# 67           the', 'effedts', 'is', 'what', 'merchants', 'call', 'neat', 'jlock', 'when', 'a'
# 68                     draw', 'on', 'partner', 'charge', 'cash', 'or', 'e', 'f', 'viz', 'the'
# 69  boroughhead', 'or', 'headborough', 'called', 'also', 'boroughholder', 'or', 'burlholde...
# 70                 ones', 'from', 'the', 'salutary', 'it', 'is', 'the', 'duty', 'of', 'every'
# 71       his', 'first', 'argument', 'for', 'the', 'coitus', 'of', 'plants', 'refers', 'every'
# 72  definition', 'of', 'life', 'they', 'fpmiancoujly', 'propel', 'humours', 'strange', 'th...
# 73              not', 'the', 'name', 'of', 'argument', 'we', 'are', 'afraid', 'that', 'every'
# 74           to', 'this', 'day', 'it', 'remains', 'a', 'very', 'doubtful', 'point', 'whether'
# 75     render', 'the', 'fubjeft', 'ridiculous', 'try', 'puffiing', 'them', 'too', 'far', 'no'
# 76        and', 'the', 'poterium', 'to', 'the', 'moncecia', 'polyandria', 'now', 'let', 'any'
# 77       with', 'any', 'deg', 'yee', 'of', 'candor', 'upon', 'hermaphrodite', 'flowers', 'no'
# 78         have', 'the', 'lead', 'tendency', 'to', 'aflift', 'the', 'botanic', 'student', 'a'
# 79                                                        recompence', 'or', 'amends', 'thus'
# 80              wood', 'or', 'trunk', 'which', 'was', 'before', 'the', 'thickness', 'of', 'a'
# 81  it', 'from', 'hiding', 'backwards', 'breastplough', 'one', 'so', 'fafliioned', 'that',...
# 82                  a', 'steel', 'handmill', 'will', 'by', 'the', 'help', 'of', 'only', 'one'
# 83            first', 'entrance', 'but', 'was', 'to', 'leap', 'over', 'it', 'bridegroom', 'a'
# 84        hath', 'about', 'twelve', 'or', 'fifteen', 'benches', 'for', 'the', 'rowers', 'one'
# 85             a', 'bench', 'all', 'the', 'hands', 'aboard', 'are', 'soldiers', 'and', 'each'
# 86                according', 'to', 'the', 'laws', 'of', 'moses', 'the', 'brother', 'of', 'a'
# 87          because', 'usually', 'fashioned', 'like', 'the', 'mouth', 'or', 'face', 'of', 'a'
# 88                   by', 'the', 'confusion', 'of', 'species', 'that', 'is', 'to', 'say', 'a'
# 89                                                                                      or',
# 90                                             a', 'brute', 'beast', 'or', 'sexes', 'as', 'a'
# 91                                                           beast', 'or', 'sexes', 'as', 'a'
# 92              anirals', 'they', 'threw', 'upon', 'the', 'pile', 'we', 'seldom', 'find', 'a'
# 93              this', 'art', 'without', 'a', 'licence', 'in', 'form', 'which', 'gave', 'the'
#
#    term  \
# 0   man
# 1   man
# 2   man
# 3   man
# 4   man
# 5   man
# 6   man
# 7   man
# 8   man
# 9   man
# 10  man
# 11  man
# 12  man
# 13  man
# 14  man
# 15  man
# 16  man
# 17  man
# 18  man
# 19  man
# 20  man
# 21  man
# 22  man
# 23  man
# 24  man
# 25  man
# 26  man
# 27  man
# 28  man
# 29  man
# ..  ...
# 64  man
# 65  man
# 66  man
# 67  man
# 68  man
# 69  man
# 70  man
# 71  man
# 72  man
# 73  man
# 74  man
# 75  man
# 76  man
# 77  man
# 78  man
# 79  man
# 80  man
# 81  man
# 82  man
# 83  man
# 84  man
# 85  man
# 86  man
# 87  man
# 88  man
# 89  man
# 90  man
# 91  man
# 92  man
# 93  man
#
#                                                                                   words_right
# 0    'be', 'capable', 'of', 'comprehending', 'the', 'principles', 'and', 'relations', 'of'...
# 1            'who', 'can', 'learn', 'the', 'principles', 'of', 'any', 'science', 'from', 'a']
# 2       'of', 'ordinary', 'parts', 'may', 'if', 'he', 'chuffs', 'learn', 'the', 'principles']
# 3                         'of', 'known', 'veracity', 'will', 'go', 'far', 'to', 'eftabliffi']
# 4            'or', 'woman', 'taken', 'from', 'the', 'life', 'which', 'is', 'usually', 'done']
# 5     'has', 'received', 'or', 'fears', 'false', 'judgment', 'in', 'an', 'inferior', 'court']
# 6      'is', 'supposed', 'to', 'have', 'been', 'made', 'adamites', 'in', 'church', 'history']
# 7                      'was', 'created', 'and', 'there', 'is', 'the', 'st', 'ape', 'of', 'a']
# 8            'over', 'and', 'above', 'his', 'proper', 'name', 'and', 'firnarae', 'to', 'hew']
# 9         'but', 'a', 'great', 'enthujiafi', 'the', 'word', 'but', 'is', 'an', 'adverfative']
# 10            'with', 'a', 'cats', 'head', 'i', 'eheatores', 'in', 'roman', 'antiquity', 'a']
# 11         'to', 'truth', 'he', 'had', 'recourse', 'to', 'a', 'subtile', 'elastic', 'scther']
# 12                    'or', 'at', 'lead', 'as', 'the', 'mod', 'useless', 'part', 'of', 'his']
# 13        'of', 'taking', 'it', 'into', 'his', 'head', 'toadvance', 'new', 'systems', 'with']
# 14               'in', 'the', 'natural', 'hate', 'or', 'course', 'of', 'think', 'ing', 'did']
# 15               'and', 'a', 'woman', 'to', 'marry', 'each', 'other', 'affiche', 'a', 'term']
# 16                'at', 'twelve', 'years', 'of', 'age', 'ought', 'to', 'take', 'the', 'oath']
# 17       'or', 'voman', 'being', 'then', 'capable', 'of', 'ading', 'for', 'themselves', 'of']
# 18        'lies', 'under', 'an', 'obligation', 'to', 'perform', 'thus', 'we', 'meet', 'with']
# 19          'is', 'also', 'neceflary', 'to', 'pulh', 'them', 'off', 'with', 'a', 'pitchfork']
# 20              'and', 'black', 'woman', 'and', 'at', 'a', 'didanee', 'might', 'be', 'taken']
# 21            'and', 'money', 'due', 'by', 'him', 'when', 'two', 'quantities', 'equal', 'in']
# 22                   'and', 'i', 'oo', 'due', 'by', 'him', 'balance', 'each', 'other', 'and']
# 23                   'more', 'than', 'if', 'all', 'had', 'paid', 'qu', 'how', 'many', 'were']
# 24           'f', 'r', 'one', 'of', 'its', 'divifors', 'since', 'in', 'this', 'fubflitution']
# 25    'having', 'the', 'parcel', 'upon', 'which', 'his', 'name', 'is', 'fixed', 'allowances']
# 26         'being', 'permitted', 'to', 'live', 'among', 'them', 'only', 'at', 'a', 'certain']
# 27       'for', 'the', 'lords', 'sake', 'they', 'consider', 'the', 'kingdom', 'of', 'christ']
# 28        'is', 'not', 'like', 'hairs', 'as', 'they', 'are', 'commonly', 'represented', 'in']
# 29                'one', 'lying', 'above', 'the', 'other', 'it', 'is', 'not', 'always', 'of']
# ..                                                                                        ...
# 64              'could', 'become', 'as', 'perfect', 'in', 'this', 'life', 'as', 'he', 'hall']
# 65       'and', 'four', 'or', 'five', 'feet', 'asunder', 'used', 'particularly', 'at', 'the']
# 66          'ffiould', 'not', 'buy', 'a', 'lightbodied', 'horse', 'and', 'one', 'that', 'is']
# 67    'begins', 'trade', 'the', 'inventory', 'must', 'be', 'gathered', 'from', 'a', 'survey']
# 68            'you', 'deliver', 'the', 'bill', 'to', 'dr', 'to', 'partner', 'bis', 'accompt']
# 69            'of', 'the', 'decenna', 'or', 'hundred', 'chofea', 'to', 'speak', 'and', 'act']
# 70          'to', 'point', 'out', 'the', 'remedy', 'for', 'calamities', 'of', 'this', 'kind']
# 71                 'to', 'the', 'evidences', 'of', 'his', 'senses', 'do', 'we', 'not', 'see']
# 72       'of', 'linnaeuss', 'capacity', 'or', 'indeed', 'of', 'any', 'capacity', 'at', 'all']
# 73   'of', 'common', 'sense', 'will', 'conclude', 'that', 'they', 'never', 'were', 'endowed']
# 74   'and', 'most', 'quadrupedes', 'derive', 'their', 'existence', 'from', 'the', 'same', ...
# 75   'ever', 'blundered', 'more', 'remarkably', 'in', 'this', 'refpedt', 'than', 'linnaeus...
# 76   'seriously', 'consider', 'the', 'unavoidable', 'consequences', 'that', 'would', 'foll...
# 77                                                                'can', 'determine', 'with']
# 78   'would', 'not', 'naturally', 'expert', 'to', 'meet', 'with', 'disgusting', 'strokes',...
# 79  te', 'is', 'a', 'cbmpenfation', 'for', 'a', 'man', 'slain', 'there', 'are', 'likewise'...
# 80                 'is', 'scarce', 'left', 'equal', 'to', 'that', 'of', 'his', 'leg', 'this']
# 81      'may', 'hove', 'it', 'before', 'him', 'breastwork', 'the', 'same', 'with', 'parapet']
# 82               'grind', 'six', 'or', 'eight', 'bushels', 'in', 'an', 'hour', 'and', 'will']
# 83   'newly', 'married', 'the', 'spouse', 'of', 'the', 'bride', 'the', 'spartan', 'bridegr...
# 84             'to', 'a', 'bench', 'all', 'the', 'hands', 'aboard', 'are', 'soldiers', 'and']
# 85           'hath', 'his', 'mufquet', 'lying', 'ready', 'under', 'his', 'oar', 'brigg', 'a']
# 86     'who', 'died', 'without', 'children', 'was', 'obliged', 'to', 'marry', 'the', 'widow']
# 87        'or', 'other', 'animal', 'bucentaur', 'a', 'galeas', 'or', 'large', 'galley', 'of']
# 88                    'or', 'woman', 'with', 'a', 'brute', 'beast', 'or', 'sexes', 'as', 'a']
# 89   'with', 'a', 'brute', 'beast', 'or', 'sexes', 'as', 'a', 'man', 'with', 'a', 'man', '...
# 90   'with', 'a', 'man', 'or', 'man', 'unnaturally', 'with', 'a', 'woman', 'it', 'is', 'sa...
# 91   'with', 'a', 'man', 'or', 'man', 'unnaturally', 'with', 'a', 'woman', 'it', 'is', 'sa...
# 92   'of', 'quality', 'copfumed', 'without', 'a', 'number', 'of', 'slaves', 'and', 'captiv...
# 93          'upon', 'evidence', 'of', 'his', 'abilities', 'a', 'power', 'to', 'kill', 'meat']
#
# [94 rows x 3 columns]
